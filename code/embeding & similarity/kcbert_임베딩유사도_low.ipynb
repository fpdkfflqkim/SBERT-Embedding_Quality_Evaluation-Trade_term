# %%
import pandas as pd
import numpy as np

# %%
kcbert_voc_low = np.load(r"C:\Users\user\Desktop\학술대회 2차\벡터\kcbert_voc_low.npy")
kcbert_sen_low = np.load(r"C:\Users\user\Desktop\학술대회 2차\벡터\kcbert_sen_low.npy")

# %%
from sklearn.metrics.pairwise import cosine_similarity

cos_dis = cosine_similarity(kcbert_voc_low, kcbert_sen_low)

# %%
cos_dis
# Out:
# array([[0.719005  , 0.54911596, 0.5579538 , ..., 0.68641305, 0.69954085,
#         0.7037597 ],
#        [0.53977156, 0.57750314, 0.5917007 , ..., 0.64933693, 0.64583254,
#         0.63836133],
#        [0.6142519 , 0.4531911 , 0.47782826, ..., 0.6100622 , 0.66389847,
#         0.657169  ],
#        ...,
#        [0.6331723 , 0.47212654, 0.5382759 , ..., 0.7439455 , 0.6490927 ,
#         0.6739853 ],
#        [0.62337035, 0.5811275 , 0.5770772 , ..., 0.70658016, 0.92175376,
#         0.6681878 ],
#        [0.56843454, 0.4523671 , 0.42686   , ..., 0.581566  , 0.66653734,
#         0.6942291 ]], dtype=float32)

# %%
cos_dis_same = []

for i in range(len(cos_dis)):
    same = cos_dis[i][i]
    #print(same)
    cos_dis_same.append([i, same])

# %%
cos_dis_same_df = pd.DataFrame(cos_dis_same, columns=["index","자기자신유사도"])

# %%
cos_dis_same_df
# Out:
#      index   자기자신유사도
# 0        0  0.719005
# 1        1  0.577503
# 2        2  0.477828
# 3        3  0.629335
# 4        4  0.663981
# ..     ...       ...
# 195    195  0.685462
# 196    196  0.624216
# 197    197  0.743945
# 198    198  0.921754
# 199    199  0.694229
#
# [200 rows x 2 columns]

# %%
same_mean = np.mean(same)
same_mean
# Out:
# 0.6942291

# %%
cos_dis_list = cos_dis.tolist()

# %%
from tqdm import tqdm
self_orders=[]

for i in tqdm(range(len(cos_dis))):
    self_num=cos_dis_list[i][i]
    case=cos_dis_list[i]
    new_case=sorted(case,reverse=True)
    self_order=new_case.index(self_num)
    
    self_case=[str(i)+'번째 자기자신 순서와의 유사도 등수',int(self_order) + 1]
    self_orders.append(self_case)
# Out:
# 100%|██████████| 200/200 [00:00<00:00, 57080.89it/s]

# %%
self_orders
# Out:
# [['0번째 자기자신 순서와의 유사도 등수', 3],
#  ['1번째 자기자신 순서와의 유사도 등수', 122],
#  ['2번째 자기자신 순서와의 유사도 등수', 175],
#  ['3번째 자기자신 순서와의 유사도 등수', 16],
#  ['4번째 자기자신 순서와의 유사도 등수', 13],
#  ['5번째 자기자신 순서와의 유사도 등수', 32],
#  ['6번째 자기자신 순서와의 유사도 등수', 66],
#  ['7번째 자기자신 순서와의 유사도 등수', 5],
#  ['8번째 자기자신 순서와의 유사도 등수', 3],
#  ['9번째 자기자신 순서와의 유사도 등수', 22],
#  ['10번째 자기자신 순서와의 유사도 등수', 115],
#  ['11번째 자기자신 순서와의 유사도 등수', 1],
#  ['12번째 자기자신 순서와의 유사도 등수', 123],
#  ['13번째 자기자신 순서와의 유사도 등수', 34],
#  ['14번째 자기자신 순서와의 유사도 등수', 70],
#  ['15번째 자기자신 순서와의 유사도 등수', 68],
#  ['16번째 자기자신 순서와의 유사도 등수', 10],
#  ['17번째 자기자신 순서와의 유사도 등수', 22],
#  ['18번째 자기자신 순서와의 유사도 등수', 1],
#  ['19번째 자기자신 순서와의 유사도 등수', 128],
#  ['20번째 자기자신 순서와의 유사도 등수', 54],
#  ['21번째 자기자신 순서와의 유사도 등수', 9],
#  ['22번째 자기자신 순서와의 유사도 등수', 10],
#  ['23번째 자기자신 순서와의 유사도 등수', 1],
#  ['24번째 자기자신 순서와의 유사도 등수', 4],
#  ['25번째 자기자신 순서와의 유사도 등수', 1],
#  ['26번째 자기자신 순서와의 유사도 등수', 51],
#  ['27번째 자기자신 순서와의 유사도 등수', 46],
#  ['28번째 자기자신 순서와의 유사도 등수', 153],
#  ['29번째 자기자신 순서와의 유사도 등수', 10],
#  ['30번째 자기자신 순서와의 유사도 등수', 43],
#  ['31번째 자기자신 순서와의 유사도 등수', 1],
#  ['32번째 자기자신 순서와의 유사도 등수', 175],
#  ['33번째 자기자신 순서와의 유사도 등수', 137],
#  ['34번째 자기자신 순서와의 유사도 등수', 92],
#  ['35번째 자기자신 순서와의 유사도 등수', 63],
#  ['36번째 자기자신 순서와의 유사도 등수', 4],
#  ['37번째 자기자신 순서와의 유사도 등수', 76],
#  ['38번째 자기자신 순서와의 유사도 등수', 97],
#  ['39번째 자기자신 순서와의 유사도 등수', 53],
#  ['40번째 자기자신 순서와의 유사도 등수', 6],
#  ['41번째 자기자신 순서와의 유사도 등수', 164],
#  ['42번째 자기자신 순서와의 유사도 등수', 31],
#  ['43번째 자기자신 순서와의 유사도 등수', 55],
#  ['44번째 자기자신 순서와의 유사도 등수', 1],
#  ['45번째 자기자신 순서와의 유사도 등수', 160],
#  ['46번째 자기자신 순서와의 유사도 등수', 1],
#  ['47번째 자기자신 순서와의 유사도 등수', 2],
#  ['48번째 자기자신 순서와의 유사도 등수', 1],
#  ['49번째 자기자신 순서와의 유사도 등수', 85],
#  ['50번째 자기자신 순서와의 유사도 등수', 158],
#  ['51번째 자기자신 순서와의 유사도 등수', 11],
#  ['52번째 자기자신 순서와의 유사도 등수', 137],
#  ['53번째 자기자신 순서와의 유사도 등수', 44],
#  ['54번째 자기자신 순서와의 유사도 등수', 88],
#  ['55번째 자기자신 순서와의 유사도 등수', 28],
#  ['56번째 자기자신 순서와의 유사도 등수', 85],
#  ['57번째 자기자신 순서와의 유사도 등수', 2],
#  ['58번째 자기자신 순서와의 유사도 등수', 31],
#  ['59번째 자기자신 순서와의 유사도 등수', 1],
#  ['60번째 자기자신 순서와의 유사도 등수', 10],
#  ['61번째 자기자신 순서와의 유사도 등수', 1],
#  ['62번째 자기자신 순서와의 유사도 등수', 82],
#  ['63번째 자기자신 순서와의 유사도 등수', 1],
#  ['64번째 자기자신 순서와의 유사도 등수', 4],
#  ['65번째 자기자신 순서와의 유사도 등수', 134],
#  ['66번째 자기자신 순서와의 유사도 등수', 2],
#  ['67번째 자기자신 순서와의 유사도 등수', 16],
#  ['68번째 자기자신 순서와의 유사도 등수', 151],
#  ['69번째 자기자신 순서와의 유사도 등수', 121],
#  ['70번째 자기자신 순서와의 유사도 등수', 1],
#  ['71번째 자기자신 순서와의 유사도 등수', 53],
#  ['72번째 자기자신 순서와의 유사도 등수', 18],
#  ['73번째 자기자신 순서와의 유사도 등수', 123],
#  ['74번째 자기자신 순서와의 유사도 등수', 1],
#  ['75번째 자기자신 순서와의 유사도 등수', 52],
#  ['76번째 자기자신 순서와의 유사도 등수', 94],
#  ['77번째 자기자신 순서와의 유사도 등수', 38],
#  ['78번째 자기자신 순서와의 유사도 등수', 40],
#  ['79번째 자기자신 순서와의 유사도 등수', 30],
#  ['80번째 자기자신 순서와의 유사도 등수', 196],
#  ['81번째 자기자신 순서와의 유사도 등수', 15],
#  ['82번째 자기자신 순서와의 유사도 등수', 8],
#  ['83번째 자기자신 순서와의 유사도 등수', 82],
#  ['84번째 자기자신 순서와의 유사도 등수', 11],
#  ['85번째 자기자신 순서와의 유사도 등수', 2],
#  ['86번째 자기자신 순서와의 유사도 등수', 8],
#  ['87번째 자기자신 순서와의 유사도 등수', 106],
#  ['88번째 자기자신 순서와의 유사도 등수', 17],
#  ['89번째 자기자신 순서와의 유사도 등수', 22],
#  ['90번째 자기자신 순서와의 유사도 등수', 70],
#  ['91번째 자기자신 순서와의 유사도 등수', 20],
#  ['92번째 자기자신 순서와의 유사도 등수', 66],
#  ['93번째 자기자신 순서와의 유사도 등수', 67],
#  ['94번째 자기자신 순서와의 유사도 등수', 2],
#  ['95번째 자기자신 순서와의 유사도 등수', 55],
#  ['96번째 자기자신 순서와의 유사도 등수', 34],
#  ['97번째 자기자신 순서와의 유사도 등수', 117],
#  ['98번째 자기자신 순서와의 유사도 등수', 2],
#  ['99번째 자기자신 순서와의 유사도 등수', 28],
#  ['100번째 자기자신 순서와의 유사도 등수', 7],
#  ['101번째 자기자신 순서와의 유사도 등수', 37],
#  ['102번째 자기자신 순서와의 유사도 등수', 23],
#  ['103번째 자기자신 순서와의 유사도 등수', 2],
#  ['104번째 자기자신 순서와의 유사도 등수', 28],
#  ['105번째 자기자신 순서와의 유사도 등수', 3],
#  ['106번째 자기자신 순서와의 유사도 등수', 113],
#  ['107번째 자기자신 순서와의 유사도 등수', 25],
#  ['108번째 자기자신 순서와의 유사도 등수', 2],
#  ['109번째 자기자신 순서와의 유사도 등수', 1],
#  ['110번째 자기자신 순서와의 유사도 등수', 38],
#  ['111번째 자기자신 순서와의 유사도 등수', 2],
#  ['112번째 자기자신 순서와의 유사도 등수', 147],
#  ['113번째 자기자신 순서와의 유사도 등수', 1],
#  ['114번째 자기자신 순서와의 유사도 등수', 172],
#  ['115번째 자기자신 순서와의 유사도 등수', 97],
#  ['116번째 자기자신 순서와의 유사도 등수', 7],
#  ['117번째 자기자신 순서와의 유사도 등수', 1],
#  ['118번째 자기자신 순서와의 유사도 등수', 1],
#  ['119번째 자기자신 순서와의 유사도 등수', 19],
#  ['120번째 자기자신 순서와의 유사도 등수', 89],
#  ['121번째 자기자신 순서와의 유사도 등수', 42],
#  ['122번째 자기자신 순서와의 유사도 등수', 107],
#  ['123번째 자기자신 순서와의 유사도 등수', 142],
#  ['124번째 자기자신 순서와의 유사도 등수', 33],
#  ['125번째 자기자신 순서와의 유사도 등수', 172],
#  ['126번째 자기자신 순서와의 유사도 등수', 3],
#  ['127번째 자기자신 순서와의 유사도 등수', 1],
#  ['128번째 자기자신 순서와의 유사도 등수', 1],
#  ['129번째 자기자신 순서와의 유사도 등수', 12],
#  ['130번째 자기자신 순서와의 유사도 등수', 10],
#  ['131번째 자기자신 순서와의 유사도 등수', 8],
#  ['132번째 자기자신 순서와의 유사도 등수', 64],
#  ['133번째 자기자신 순서와의 유사도 등수', 1],
#  ['134번째 자기자신 순서와의 유사도 등수', 18],
#  ['135번째 자기자신 순서와의 유사도 등수', 5],
#  ['136번째 자기자신 순서와의 유사도 등수', 27],
#  ['137번째 자기자신 순서와의 유사도 등수', 8],
#  ['138번째 자기자신 순서와의 유사도 등수', 1],
#  ['139번째 자기자신 순서와의 유사도 등수', 16],
#  ['140번째 자기자신 순서와의 유사도 등수', 68],
#  ['141번째 자기자신 순서와의 유사도 등수', 9],
#  ['142번째 자기자신 순서와의 유사도 등수', 143],
#  ['143번째 자기자신 순서와의 유사도 등수', 21],
#  ['144번째 자기자신 순서와의 유사도 등수', 37],
#  ['145번째 자기자신 순서와의 유사도 등수', 138],
#  ['146번째 자기자신 순서와의 유사도 등수', 8],
#  ['147번째 자기자신 순서와의 유사도 등수', 6],
#  ['148번째 자기자신 순서와의 유사도 등수', 15],
#  ['149번째 자기자신 순서와의 유사도 등수', 4],
#  ['150번째 자기자신 순서와의 유사도 등수', 90],
#  ['151번째 자기자신 순서와의 유사도 등수', 1],
#  ['152번째 자기자신 순서와의 유사도 등수', 6],
#  ['153번째 자기자신 순서와의 유사도 등수', 11],
#  ['154번째 자기자신 순서와의 유사도 등수', 1],
#  ['155번째 자기자신 순서와의 유사도 등수', 30],
#  ['156번째 자기자신 순서와의 유사도 등수', 1],
#  ['157번째 자기자신 순서와의 유사도 등수', 68],
#  ['158번째 자기자신 순서와의 유사도 등수', 1],
#  ['159번째 자기자신 순서와의 유사도 등수', 2],
#  ['160번째 자기자신 순서와의 유사도 등수', 2],
#  ['161번째 자기자신 순서와의 유사도 등수', 1],
#  ['162번째 자기자신 순서와의 유사도 등수', 4],
#  ['163번째 자기자신 순서와의 유사도 등수', 13],
#  ['164번째 자기자신 순서와의 유사도 등수', 3],
#  ['165번째 자기자신 순서와의 유사도 등수', 11],
#  ['166번째 자기자신 순서와의 유사도 등수', 1],
#  ['167번째 자기자신 순서와의 유사도 등수', 4],
#  ['168번째 자기자신 순서와의 유사도 등수', 1],
#  ['169번째 자기자신 순서와의 유사도 등수', 53],
#  ['170번째 자기자신 순서와의 유사도 등수', 5],
#  ['171번째 자기자신 순서와의 유사도 등수', 1],
#  ['172번째 자기자신 순서와의 유사도 등수', 2],
#  ['173번째 자기자신 순서와의 유사도 등수', 2],
#  ['174번째 자기자신 순서와의 유사도 등수', 27],
#  ['175번째 자기자신 순서와의 유사도 등수', 2],
#  ['176번째 자기자신 순서와의 유사도 등수', 1],
#  ['177번째 자기자신 순서와의 유사도 등수', 13],
#  ['178번째 자기자신 순서와의 유사도 등수', 1],
#  ['179번째 자기자신 순서와의 유사도 등수', 1],
#  ['180번째 자기자신 순서와의 유사도 등수', 68],
#  ['181번째 자기자신 순서와의 유사도 등수', 5],
#  ['182번째 자기자신 순서와의 유사도 등수', 1],
#  ['183번째 자기자신 순서와의 유사도 등수', 1],
#  ['184번째 자기자신 순서와의 유사도 등수', 1],
#  ['185번째 자기자신 순서와의 유사도 등수', 27],
#  ['186번째 자기자신 순서와의 유사도 등수', 1],
#  ['187번째 자기자신 순서와의 유사도 등수', 16],
#  ['188번째 자기자신 순서와의 유사도 등수', 6],
#  ['189번째 자기자신 순서와의 유사도 등수', 1],
#  ['190번째 자기자신 순서와의 유사도 등수', 26],
#  ['191번째 자기자신 순서와의 유사도 등수', 2],
#  ['192번째 자기자신 순서와의 유사도 등수', 18],
#  ['193번째 자기자신 순서와의 유사도 등수', 1],
#  ['194번째 자기자신 순서와의 유사도 등수', 6],
#  ['195번째 자기자신 순서와의 유사도 등수', 2],
#  ['196번째 자기자신 순서와의 유사도 등수', 28],
#  ['197번째 자기자신 순서와의 유사도 등수', 1],
#  ['198번째 자기자신 순서와의 유사도 등수', 1],
#  ['199번째 자기자신 순서와의 유사도 등수', 1]]

# %%
self_orders_num = [i[1] for i in self_orders]
np.mean(self_orders_num)
# Out:
# 38.035

# %%
self_orders_num
# Out:
# [3,
#  122,
#  175,
#  16,
#  13,
#  32,
#  66,
#  5,
#  3,
#  22,
#  115,
#  1,
#  123,
#  34,
#  70,
#  68,
#  10,
#  22,
#  1,
#  128,
#  54,
#  9,
#  10,
#  1,
#  4,
#  1,
#  51,
#  46,
#  153,
#  10,
#  43,
#  1,
#  175,
#  137,
#  92,
#  63,
#  4,
#  76,
#  97,
#  53,
#  6,
#  164,
#  31,
#  55,
#  1,
#  160,
#  1,
#  2,
#  1,
#  85,
#  158,
#  11,
#  137,
#  44,
#  88,
#  28,
#  85,
#  2,
#  31,
#  1,
#  10,
#  1,
#  82,
#  1,
#  4,
#  134,
#  2,
#  16,
#  151,
#  121,
#  1,
#  53,
#  18,
#  123,
#  1,
#  52,
#  94,
#  38,
#  40,
#  30,
#  196,
#  15,
#  8,
#  82,
#  11,
#  2,
#  8,
#  106,
#  17,
#  22,
#  70,
#  20,
#  66,
#  67,
#  2,
#  55,
#  34,
#  117,
#  2,
#  28,
#  7,
#  37,
#  23,
#  2,
#  28,
#  3,
#  113,
#  25,
#  2,
#  1,
#  38,
#  2,
#  147,
#  1,
#  172,
#  97,
#  7,
#  1,
#  1,
#  19,
#  89,
#  42,
#  107,
#  142,
#  33,
#  172,
#  3,
#  1,
#  1,
#  12,
#  10,
#  8,
#  64,
#  1,
#  18,
#  5,
#  27,
#  8,
#  1,
#  16,
#  68,
#  9,
#  143,
#  21,
#  37,
#  138,
#  8,
#  6,
#  15,
#  4,
#  90,
#  1,
#  6,
#  11,
#  1,
#  30,
#  1,
#  68,
#  1,
#  2,
#  2,
#  1,
#  4,
#  13,
#  3,
#  11,
#  1,
#  4,
#  1,
#  53,
#  5,
#  1,
#  2,
#  2,
#  27,
#  2,
#  1,
#  13,
#  1,
#  1,
#  68,
#  5,
#  1,
#  1,
#  1,
#  27,
#  1,
#  16,
#  6,
#  1,
#  26,
#  2,
#  18,
#  1,
#  6,
#  2,
#  28,
#  1,
#  1,
#  1]

# %%
self_orders_num_df = pd.DataFrame(self_orders_num,columns = ["등수"])

# %%
low_concat = pd.concat([cos_dis_same_df, self_orders_num_df], axis=1)

# %%
low_concat.to_excel(r'C:\Users\user\Desktop\학술대회 2차\결과물\kcbert_concat_low.xlsx', index=False)
